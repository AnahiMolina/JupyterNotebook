# %% [markdown]
# # Ejercicio 1

# %%
#Genere un vector llamado 𝒗𝟏 con 30 datos numéricos aleatorios con una distribución normal (𝝁 = 𝟑,𝝈𝟐 = 𝟖𝟏); usar una cifra decimal y semilla=2104. 
set.seed(2104)
v1 <- round(rnorm(30, mean = 3, sd = 9), 1)
v1
# Out:
#  [1] -4.0 10.5 -6.1  1.9 -4.8  4.2 -7.0  5.5  3.0  4.2  4.7  1.5 10.7  5.1  1.1
# [16] 16.4 11.4 10.5  2.5 12.7  4.3  4.9 -1.0  8.7 21.8 17.4 -6.6  5.7  1.2  5.4

# %%
# Genere un vector llamado 𝒗𝟐 con 30 datos de tipo caracter.  
v2 <- rep(c("a","b","c","d","e"),6)
v2
# Out:
#  [1] "a" "b" "c" "d" "e" "a" "b" "c" "d" "e" "a" "b" "c" "d" "e" "a" "b" "c" "d"
# [20] "e" "a" "b" "c" "d" "e" "a" "b" "c" "d" "e"

# %%
# Genere un vector llamado 𝒗𝟑 con 30 datos de tipo lógico.  
v3 <- rep(c(TRUE,FALSE),15)
v3
# Out:
#  [1]  TRUE FALSE  TRUE FALSE  TRUE FALSE  TRUE FALSE  TRUE FALSE  TRUE FALSE
# [13]  TRUE FALSE  TRUE FALSE  TRUE FALSE  TRUE FALSE  TRUE FALSE  TRUE FALSE
# [25]  TRUE FALSE  TRUE FALSE  TRUE FALSE

# %%
# Crear un data frame llamado DF1, concatenando los vectores 𝒗𝟏,𝒗𝟐 , 𝒗𝟑.  
DF1 = data.frame(X=v1,Y=v2,Z=v3)
DF1
# Out:
#    X    Y Z
# 1  -4.0 a  TRUE
# 2  10.5 b FALSE
# 3  -6.1 c  TRUE
# 4   1.9 d FALSE
# 5  -4.8 e  TRUE
# 6   4.2 a FALSE
# 7  -7.0 b  TRUE
# 8   5.5 c FALSE
# 9   3.0 d  TRUE
# 10  4.2 e FALSE
# 11  4.7 a  TRUE
# 12  1.5 b FALSE
# 13 10.7 c  TRUE
# 14  5.1 d FALSE
# 15  1.1 e  TRUE
# 16 16.4 a FALSE
# 17 11.4 b  TRUE
# 18 10.5 c FALSE
# 19  2.5 d  TRUE
# 20 12.7 e FALSE
# 21  4.3 a  TRUE
# 22  4.9 b FALSE
# 23 -1.0 c  TRUE
# 24  8.7 d FALSE
# 25 21.8 e  TRUE
# 26 17.4 a FALSE
# 27 -6.6 b  TRUE
# 28  5.7 c FALSE
# 29  1.2 d  TRUE
# 30  5.4 e FALSE

# %%
# Crear una lista llamada L1 que contenga a 𝒗𝟏, 𝑴𝟏 y el DF1 elaborados en esta práctica. 
L1 <- list(v1,DF1)
L1
# Out:
# [[1]]
#  [1] -4.0 10.5 -6.1  1.9 -4.8  4.2 -7.0  5.5  3.0  4.2  4.7  1.5 10.7  5.1  1.1
# [16] 16.4 11.4 10.5  2.5 12.7  4.3  4.9 -1.0  8.7 21.8 17.4 -6.6  5.7  1.2  5.4
#
# [[2]]
#       X Y     Z
# 1  -4.0 a  TRUE
# 2  10.5 b FALSE
# 3  -6.1 c  TRUE
# 4   1.9 d FALSE
# 5  -4.8 e  TRUE
# 6   4.2 a FALSE
# 7  -7.0 b  TRUE
# 8   5.5 c FALSE
# 9   3.0 d  TRUE
# 10  4.2 e FALSE
# 11  4.7 a  TRUE
# 12  1.5 b FALSE
# 13 10.7 c  TRUE
# 14  5.1 d FALSE
# 15  1.1 e  TRUE
# 16 16.4 a FALSE
# 17 11.4 b  TRUE
# 18 10.5 c FALSE
# 19  2.5 d  TRUE
# 20 12.7 e FALSE
# 21  4.3 a  TRUE
# 22  4.9 b FALSE
# 23 -1.0 c  TRUE
# 24  8.7 d FALSE
# 25 21.8 e  TRUE
# 26 17.4 a FALSE
# 27 -6.6 b  TRUE
# 28  5.7 c FALSE
# 29  1.2 d  TRUE
# 30  5.4 e FALSE

# %%
# Identificar el número de elementos de la lista L1.
length (L1)
# Out:
# [1] 2
