# %% [markdown]
# # O

# %%
import time
import matplotlib.pyplot as plt

# %%
def linear_search(arr, target):
    for i in arr:
        if i == target:
            return True
    return False

# %%
sizes = [100, 500, 1000, 2000, 3000, 4000, 5000]
times = []

for size in sizes:
    data = list(range(size))
    target = size - 1  # el peor caso es buscar el último elemento

    start = time.time()
    linear_search(data, target)
    end = time.time()

    times.append(end - start)

# %%
plt.figure(figsize=(8, 5))
plt.plot(sizes, times, marker='o', label="O(n) - Búsqueda lineal")
plt.xlabel("Tamaño del arreglo")
plt.ylabel("Tiempo de ejecución (segundos)")
plt.title("Complejidad O(n): Búsqueda lineal")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Omega Ω

# %%
def linear_search(arr, target):
    for i in arr:
        if i == target:
            return True
    return False

# %%
sizes = [100, 500, 1000, 2000, 3000, 4000, 5000]
times = []

# %%
for size in sizes:
    data = list(range(size))
    target = 0 # mejor caso: el primer elemento

    start= time.time()
    linear_search(data, target)
    end = time.time()

    times.append(end - start)

# %%
plt.figure(figsize=(8,5))
plt.plot(sizes, times, marker='o', color="green", label="Ω(1) - Mejor caso búsqueda lineal")
plt.xlabel("Tamaño del arreglo")
plt.ylabel("Tiempo de ejecución (segundos)")
plt.title("Ω(1) - Mejor caso búsqueda lineal")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Theta θ

# %%
def linear_search(arr, target):
    for i in arr:
        if i == target:
            return True
    return False

# %%
sizes = [100, 500, 1000, 2000, 3000, 4000, 5000]
times = []

# %%
for size in sizes:
    data = list(range(size))
    target = size // 2 # promedio: elemento a la mitad

    start= time.time()
    linear_search(data, target)
    end = time.time()

    times.append(end - start)

# %%
plt.figure(figsize=(8,5))
plt.plot(sizes, times, marker='o', color="orange", label="θ(n) - Búsqueda lineal (promedio)")
plt.xlabel("Tamaño del arreglo")
plt.ylabel("Tiempo de ejecución (segundos)")
plt.title("Caso promedio (θ): Búsqueda lineal")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
